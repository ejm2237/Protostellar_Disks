# %%
import matplotlib.pyplot as plt
# %store -r PostPertTemp
# %store -r PrePertTemp
# %store -r xGrid
# %store -r yGrid

c = plt.contourf(xGrid, yGrid, PostPertTemp - PrePertTemp, 30)
plt.xlabel('r [AU]')
plt.ylabel(r'$\pi/2-\theta$')
plt.title('Relative Temperature Contour')
plt.xscale('log')
cb = plt.colorbar(c)
cb.set_label('T [K]', rotation=270.)

c = plt.contour(xGrid, yGrid, PostPertTemp - PrePertTemp, 10,  colors='k', linestyles='solid')
plt.clabel(c, inline=1, fontsize=10)
plt.show()

# %%
#Create the default view
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
# %store -r xGrid
# %store -r yGrid

xGrid, yGrid = np.meshgrid(xGrid, yGrid)

ax.plot_surface(xGrid, yGrid, PostPertTemp - PrePertTemp)
plt.show()

#Create the distance axis view
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
# %store -r xGrid
# %store -r yGrid

xGrid, yGrid = np.meshgrid(xGrid, yGrid)

ax.plot_surface(xGrid, yGrid, PostPertTemp - PrePertTemp)
ax.view_init(0, -90)
plt.show()

#Create the angle axis view
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
# %store -r xGrid
# %store -r yGrid

xGrid, yGrid = np.meshgrid(xGrid, yGrid)

ax.plot_surface(xGrid, yGrid, PostPertTemp - PrePertTemp)
ax.view_init(0, 0)
plt.show()
